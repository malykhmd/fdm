# %% [markdown]
# # Как использовать схемы высокого порядка
# ## Общие замечания

# %% [markdown]
# Схемы высоких порядков (9-14) задаются при помощи метода construct_high_order_schemes, определенного в классе таблиц Бутчера:

# %%
load("fdm.sage")

# %%
B = construct_high_order_schemes()

# %% [markdown]
# Всего таблиц:

# %%
len(B)
# Out:
# 25

# %%
[b.order() for b in B]
# Out:
# [9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  14,
#  14]

# %% [markdown]
# Создадим список всех таблиц 14-го порядка

# %%
B = construct_high_order_schemes([14])

# %%
len(B)
# Out:
# 2

# %% [markdown]
# Выведем первую таблицу на печать

# %%
B[0].latex(field=RealField(11))
# Out:
# \begin{array}{c|ccccccccccccccccccccccccccccccccccc}
#  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.111 & 0.111 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.555 & -0.833 & 1.39 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.833 & 0.208 &  & 0.625 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.333 & 0.193 &  & 0.220 & -0.0800 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 1.00 & 0.100 &  &  & 0.400 & 0.500 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.670 & 0.103 &  &  & 0.122 & 0.483 & -0.0381 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# ...

# %% [markdown]
# $$
# \begin{array}{c|ccccccccccccccccccccccccccccccccccc}
#  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.111 & 0.111 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.555 & -0.833 & 1.39 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.833 & 0.208 &  & 0.625 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.333 & 0.193 &  & 0.220 & -0.0800 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 1.00 & 0.100 &  &  & 0.400 & 0.500 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.670 & 0.103 &  &  & 0.122 & 0.483 & -0.0381 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.297 & 0.124 &  &  &  & 0.226 & 0.0138 & -0.0672 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.728 & 0.0937 &  &  &  &  & -0.00613 & 0.216 & 0.424 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.140 & 0.0839 &  &  &  &  & -0.0118 & -0.247 & 0.0978 & 0.218 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.701 & 0.0615 &  &  &  &  & 0.00592 & 0.470 & 0.300 & -0.248 & 0.111 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.364 & 0.0420 &  &  &  &  & -0.00318 & 0.807 & 0.0976 & 0.779 & 0.205 & -1.56 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.263 & 0.0438 &  &  &  &  &  &  &  & 0.00624 & 0.200 & -0.00806 & 0.0211 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.0392 & 0.0284 &  &  &  &  &  &  &  & 0.00249 & 0.0230 & -0.00322 & 0.00989 & -0.0213 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.812 & 0.344 &  &  &  &  &  &  &  & 0.210 & 1.03 & 0.00600 & 0.856 & -0.977 & -0.660 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.167 & -0.0144 &  &  &  &  &  &  &  & -0.0367 & 0.0349 & 0.0362 & -0.0266 & 0.0447 & 0.125 & 0.00415 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.900 & 0.356 &  &  &  &  &  &  &  & -0.450 & 0.430 & 0.512 & 0.908 & -1.24 & -0.649 & 0.252 & 0.780 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.0641 & 0.0131 &  &  &  &  &  &  &  &  &  &  &  & -0.0000932 & 0.0505 & 8.05 \times 10^{-7} & 0.000592 & -4.02 \times 10^{-7} &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.204 & 0.0208 &  &  &  &  &  &  &  &  &  &  &  & 0.000583 & -0.00802 & 4.04 \times 10^{-6} & 0.0854 & -2.05 \times 10^{-6} & 0.105 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.398 & 1.43 &  &  &  &  &  &  &  &  &  &  &  & -0.254 & -7.39 & 0.00379 & -4.86 & -0.00179 & 7.83 & 3.63 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.596 & 11.8 &  &  &  &  &  &  &  &  &  &  &  & 7.94 & -55.8 & 0.0912 & -12.1 & -0.0397 & 53.8 & -4.25 & -0.810 &  &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.642 & -148. &  &  &  &  &  &  &  &  &  &  &  & -93.4 & 701. & -1.11 & 169. & 0.491 & -677. & 34.6 & 13.3 & 1.25 &  &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.950 & -9.60 &  &  &  &  &  &  &  &  &  &  &  & -4.57 & 45.1 & -0.0713 & 10.8 & 0.126 & -43.1 & 1.22 & 0.537 & 0.422 & 0.0859 &  &  &  &  &  &  &  &  &  &  &  &  & \\
# 0.149 & -10.0 &  &  &  &  &  &  &  & -0.0367 & 0.0349 & 0.0362 & -0.0266 & -6.38 & 47.8 & -0.0695 & 12.2 & 0.0120 & -46.3 & 1.74 & 1.01 & 0.0209 & 0.0210 & 0.00952 &  &  &  &  &  &  &  &  &  &  &  & \\
# 1.36 & -406. &  &  &  &  &  &  &  & 0.210 & 1.03 & 0.00600 & 0.856 & -255. & 1930. & -3.04 & 472. & 1.57 & -1860. & 93.6 & 34.8 & 3.21 & -0.460 & -0.0871 & -7.62 &  &  &  &  &  &  &  &  &  &  & \\
# 0.0599 & 3.41 &  &  &  &  &  &  &  & 0.00249 & 0.0230 & -0.00322 & 0.00989 & 2.20 & -16.1 & -0.129 & -8.99 & -0.00348 & 15.6 & -0.719 & -0.347 & -0.00662 & -0.00778 & -0.00356 & 4.95 & 0.154 &  &  &  &  &  &  &  &  &  & \\
# 0.260 & 32.2 &  &  &  &  & -0.00318 & 0.807 & 0.0976 & 0.779 & 0.205 & -1.56 &  & 16.5 & -154. & 1.57 & 5.46 & -0.0504 & 153. & 6.47 & -2.95 & -0.0665 & -0.0462 & -0.0204 & -54.9 & -1.36 & -1.57 &  &  &  &  &  &  &  &  & \\
# 0.716 & -16.6 &  &  &  &  & 0.00592 & 0.470 & 0.300 & -0.248 & 0.111 &  & -0.492 & -11.6 & 79.9 & -0.384 & 6.36 & -0.133 & -80.7 & -0.803 & 2.60 & -0.302 & 0.221 & 0.0828 & 19.5 & 0.269 & 1.63 & 0.492 &  &  &  &  &  &  &  & \\
# 0.147 & 0.0839 &  &  &  &  & -0.0118 & -0.247 & 0.0978 & 0.218 &  & 0.138 & 0.0440 &  & -0.514 & 0.826 & 26.5 &  &  &  &  &  &  &  & -26.5 & -0.826 & 0.514 & -0.0440 & -0.138 &  &  &  &  &  &  & \\
# 0.300 & 0.124 &  &  &  & 0.226 & 0.0138 & -0.0672 &  &  & -0.856 & -1.96 & -0.232 &  & 4.30 & -2.93 & -85.2 &  &  &  &  &  &  &  & 85.2 & 2.93 & -4.30 & 0.232 & 1.96 & 0.856 &  &  &  &  &  & \\
# 0.670 & 0.103 &  &  & 0.122 & 0.483 & -0.0381 &  & -0.550 &  & -0.712 & -0.584 &  &  & 2.11 & -0.0837 & 5.10 &  &  &  &  &  &  &  & -5.10 & 0.0837 & -2.11 &  & 0.584 & 0.712 & 0.550 &  &  &  &  & \\
# 0.330 & 0.193 &  & 0.220 & -0.0800 &  &  & 0.110 & -0.254 &  & 0.866 & 3.32 &  &  & -12.0 & 0.477 & -29.0 &  &  &  &  &  &  &  & 29.0 & -0.477 & 12.0 &  & -3.32 & -0.866 & 0.254 & -0.110 &  &  &  & \\
# 0.555 & -0.833 & 1.39 &  &  & -0.750 &  & -0.492 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & 0.492 & 0.750 &  &  & \\
# 0.111 & 0.111 &  & -0.222 &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & 0.222 &  & \\
# 1.00 & 0.286 & 0.292 & 0.219 &  & 0.164 &  & 0.218 & 0.180 &  & 0.206 & 0.243 & 0.246 & -3.45 & 0.229 & 0.283 & 3.30 & -0.224 & -0.708 & 3.21 & 1.41 & -0.151 & 0.372 & 0.253 & -3.30 & -0.283 & -0.229 & -0.246 & -0.243 & -0.206 & -0.180 & -0.218 & -0.164 & -0.219 & -0.292 & \\
# \hline
#  & 0.0179 & 0.00586 & 0.0117 &  & 0.0176 &  & 0.0234 & 0.0293 &  & 0.0352 & 0.0410 & 0.0469 &  & 0.0527 & 0.0586 & 0.0645 &  & 0.105 & 0.171 & 0.206 & 0.206 & 0.171 & 0.105 & -0.0645 & -0.0586 & -0.0527 & -0.0469 & -0.0410 & -0.0352 & -0.0293 & -0.0234 & -0.0176 & -0.0117 & -0.00586 & 0.0179
# \end{array}
# $$

# %% [markdown]
# ## Пример решения системы ОДУ по схеме 14-го порядка

# %%
var("t,x1,x2")
pr1=Initial_problem([x1,x2],[x2,-x1],[0,1],10)
s=erk(pr1,N=10, tableau=B[0])

# %%
s.plot(t,x1)+plot(sin(t),(t,0,10),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Определение порядка схемы по методу Ричардсона

# %%
M=8
@parallel
def foo(n):
    return erk(pr1,N=10*2^n,tableau=B[0], field=RealField(100))
L=foo([n for n in range(M)])
L1=list(L)

# %%
richardson_plot([L1[n][1] for n in range(M)],x1,9, nmin=2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
load("fdm.sage")
var("x1,x2,t")
pr=Initial_problem([x1,x2], [x2,-x1],[0,1], 10)
P=erk(pr, N=40)
P.plot(t,x1) + plot(sin,(0,10),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
P.zeros(x1)
# Out:
# [3.1416881403498973, 6.283384235094009, 9.42507238006011]

# %%
L=[erk(pr, N=2^n*10) for n in range(10)]

# %%
richardson_plot_zeros(L, x1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
richardson_plot_zeros(L, x1, num=2, nmin=1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
richardson_zeros(L[1],L[2], x1)
# Out:
# [3.1416881403498973, 0.0000886600548851331]

# %%
L[2].zeros(x1)[0]-RR(pi)
# Out:
# 0.0000954867601041798

# %%
richardson_zeros(L[-1],L[-2], x1)
# Out:
# [3.141592653590175, 3.80702876630797e-13]

# %%
L[-1].zeros(x1)[0]-RR(pi)
# Out:
# 3.81916720471054e-13
